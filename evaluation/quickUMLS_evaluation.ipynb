# %%
from quickumls import QuickUMLS

# %%
matcher = QuickUMLS("../../quickumls", overlapping_criteria='score', threshold=0.6)
result = matcher.match("active treatment", best_match=True, ignore_syntax=False)

# %%
result
# Out:
# [[{'start': 7,
#    'end': 16,
#    'ngram': 'treatment',
#    'term': 'treatment',
#    'cui': 'C0087111',
#    'similarity': 1.0,
#    'semtypes': {'T061'},
#    'preferred': 1},
#   {'start': 7,
#    'end': 16,
#    'ngram': 'treatment',
#    'term': 'treatment',
#    'cui': 'C3887704',
#    'similarity': 1.0,
#    'semtypes': {'T058'},
#    'preferred': 1},
#   {'start': 7,
#    'end': 16,
#    'ngram': 'treatment',
#    'term': 'treatments',
#    'cui': 'C0087111',
#    'similarity': 0.875,
#    'semtypes': {'T061'},
#    'preferred': 1},
#   {'start': 7,
#    'end': 16,
#    'ngram': 'treatment',
#    'term': 'cotreatment',
#    'cui': 'C0009429',
#    'similarity': 0.7777777777777778,
#    'semtypes': {'T061'},
#    'preferred': 1},
#   {'start': 7,
#    'end': 16,
#    'ngram': 'treatment',
#    'term': 'Retreatment',
#    'cui': 'C5238861',
#    'similarity': 0.7777777777777778,
#    'semtypes': {'T033'},
#    'preferred': 1},
#   {'start': 7,
#    'end': 16,
# ...
